# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'D:\Insurance_ml_Project\Insurance_Premium_Predection\premium\artifact\data_ingestion\2022-08-03-11-01-39\raw_data\insurance.csv')

# %%
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df["cat_age"] = pd.cut(
                df["age"],
                bins=[0.0, 20.0, 30.0, 40.0, 50.0, np.inf],
                labels=[1,2,3,4,5]
            )

# %%
df["cat_age"]
# Out:
# 0       1
# 1       1
# 2       2
# 3       3
# 4       3
#        ..
# 1333    4
# 1334    1
# 1335    1
# 1336    2
# 1337    5
# Name: cat_age, Length: 1338, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
df["cat_age"].unique()
# Out:
# [1, 2, 3, 4, 5]
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
df["age"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.pie(df.cat_age.value_counts(), labels = df.cat_age.value_counts().index)
plt.show()

# %%
df['children'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.dtypes
# Out:
# age            int64
# sex           object
# bmi          float64
# children       int64
# smoker        object
# region        object
# expenses     float64
# cat_age     category
# dtype: object

# %%
df['expenses'] = df['expenses'].astype('float64')
df['expenses']
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# cat_age     0
# dtype: int64

# %%
df['children'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
corr = df.corr()

# %%
corr
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %%
plt.figure(figsize=(8,7))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(ncols = 3, figsize = (15,6), squeeze=True)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.4, hspace=None)
df.plot(kind='scatter', x='age', y='expenses', ax=axes[1])
df.plot(kind='scatter', x='children', y='expenses', ax=axes[0])
df.plot(kind='scatter', x='bmi', y='expenses', ax=axes[2])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (15,10))

df.plot(kind='hist', y='age', ax=axes[0][0], color = 'blue')
df.plot(kind='hist', y='bmi', ax=axes[0][1], color = 'orange', bins = 54)
df.plot(kind='hist', y='children', ax=axes[1][0], color = 'brown', bins = 6)
df.plot(kind='hist', y='expenses', ax=axes[1][1], color = 'green', bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
palette=['#37CC43','#3EA2FF']
fig, axes = plt.subplots(ncols = 3, figsize = (15,8), squeeze=True)
sns.scatterplot(x='bmi', y='expenses', ax=axes[0], data=df,hue='sex', palette=palette)
sns.scatterplot(x='bmi', y='expenses', ax=axes[1], data=df,hue='smoker', palette=palette)
sns.scatterplot(x='bmi', y='expenses', ax=axes[2], data=df,hue='region')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
fig, axes = plt.subplots(ncols=3, figsize = (15,6))
df['sex'].value_counts().plot(kind='bar', color = 'orange', ax=axes[0],title="Sex", legend = 'sex') 
df['region'].value_counts().plot(kind='bar', color = 'green', ax=axes[1],title="Region", legend = 'region')
df['smoker'].value_counts().plot(kind='bar', ax=axes[2],title="Smoker", legend = 'smoker')
# Out:
# <AxesSubplot:title={'center':'Smoker'}>

# %%
palette=['#EB5050','#3EA2FF']
sns.catplot(x='sex', y='expenses', kind='boxen', palette=palette, data=df)

# %%
palette=['#EB5050','#2DFFAB'] 
sns.catplot(x='sex', y='expenses', kind='boxen', hue='smoker', palette=palette, data=df)

# %%
from scipy import stats
from scipy.stats import norm
fig =plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.distplot(df['expenses'], fit=norm)
(mu,sigma)= norm.fit(df['expenses'])
plt.legend(['For Normal dist. mean: {:.2f} | std: {:.2f}'.format(mu,sigma)])
plt.ylabel('Frequency')
plt.xlabel('Expenses')
plt.title('Distribution of Charges')
# Out:
# c:\Users\91886\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Charges')
